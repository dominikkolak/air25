# %%
import sys
sys.path.insert(0, '/home/dom/AIR/air25')

from pipeline import run_pipeline

results = run_pipeline()

# %%
for r in results[:20]:
    print(f"Claim: {r['claim'][:50]}... : {r['verdict']} | [{r['votes']}]")
# Out:
# Claim: Global warming is driving polar bears toward extin... : NOT_ENOUGH_INFO | [{'REFUTES': 0.5456916689872742, 'SUPPORTS': 0.6665968894958496}]
# Claim: The sun has gone into lockdown which could cause f... : REFUTES | [{'REFUTES': 3.256580114364624}]
# Claim: The polar bear population has been growing.... : SUPPORTS | [{'SUPPORTS': 1.7042924165725708}]
# Claim: Ironic study finds more CO2 has slightly cooled th... : REFUTES | [{'REFUTES': 1.2532666325569153}]
# Claim: Human additions of CO2 are in the margin of error ... : NOT_ENOUGH_INFO | [{'NOT_ENOUGH_INFO': 4.364699304103851}]
# Claim: They tell us that we are the primary forces contro... : REFUTES | [{'REFUTES': 0.6211366653442383}]
# Claim: The Great Barrier Reef is experiencing the most wi... : NOT_ENOUGH_INFO | [{'SUPPORTS': 0.9932665824890137, 'REFUTES': 0.6666113138198853}]
# Claim: its not a pollutant that threatens human civilizat... : REFUTES | [{'REFUTES': 4.987630128860474}]
# ...
