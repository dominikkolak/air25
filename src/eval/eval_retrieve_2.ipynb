# %%
# Dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from collections import defaultdict

import sys
sys.path.insert(0, '/home/dom/AIR/air25')

from src.config import CLAIMS_PATH, EVIDENCE_PATH, MAPPINGS_PATH, EVIDENCE_EMBEDDINGS_PATH, CLAIMS_EMBEDDINGS_PATH
from src.a2.retrieve import retrieve_all

# %%
# Load Data

claims = pd.read_csv(CLAIMS_PATH)
evidences = pd.read_csv(EVIDENCE_PATH)
mappings = pd.read_csv(MAPPINGS_PATH)

vec_c = np.load(CLAIMS_EMBEDDINGS_PATH)
vec_e = np.load(EVIDENCE_EMBEDDINGS_PATH)

# %%
# Ground Truth

valid_claim_ids = set(claims['claim_id']) # DISPUTE still somehow ended up in ground truth
evidence_id_to_idx = {eid: idx for idx, eid in enumerate(evidences['evidence_id'])}

idx_to_claim_id = dict(enumerate(claims['claim_id']))

ground_truth = defaultdict(set)
for _, row in mappings.iterrows():
    if (row['label'] in ['SUPPORTS', 'REFUTES']
        and row['evidence_id'] in evidence_id_to_idx
        and row['claim_id'] in valid_claim_ids):
        ground_truth[row['claim_id']].add(evidence_id_to_idx[row['evidence_id']])

ground_truth = dict(ground_truth)

# %%
# Eval Function

def evaluate_retrieval(vec_c, vec_e, ground_truth, idx_to_claim_id, k=10):
    retrieved = retrieve_all(vec_c, vec_e, k=k)

    results = []
    for row_idx, claim_id in idx_to_claim_id.items():
        if claim_id not in ground_truth:
            continue

        expected = ground_truth[claim_id]
        retrieved_idx = {idx for idx, _ in retrieved[row_idx]}
        hits = expected & retrieved_idx

        results.append({
            'claim_id': claim_id,
            'expected': len(expected),
            'found': len(hits),
            'recall': len(hits) / len(expected)
        })

    return pd.DataFrame(results), retrieved

# %%
# Recall@k

k_values = [5, 10, 20, 50, 100]
recall_scores = []

for k in k_values:
    results_df, _ = evaluate_retrieval(vec_c, vec_e, ground_truth, idx_to_claim_id, k=k)
    mean_recall = results_df['recall'].mean()
    recall_scores.append(mean_recall)
    print(f"Recall@{k:3d}: {mean_recall:.2%}")
# Out:
# Recall@  5: 32.87%
# Recall@ 10: 42.58%
# Recall@ 20: 54.15%
# Recall@ 50: 68.92%
# Recall@100: 78.73%

# %%
# Plot Recall@k

plt.plot(k_values, recall_scores)
plt.show()

# %%
# Results

K = 50 # Best Tradeoff with all-MiniLM-L6-v2

results_df, retrieved = evaluate_retrieval(vec_c, vec_e, ground_truth, idx_to_claim_id, k=K)

print(f"Mean Recall: {results_df['recall'].mean():.2%}")
print(f"Perfect Recall: {(results_df['recall'] == 1).sum()} / {len(results_df)}")
print(f"Zero Recall: {(results_df['recall'] == 0).sum()} / {len(results_df)}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 7
#       3 K = 50 # Best Tradeoff with all-MiniLM-L6-v2
#       5 results_df, retrieved = evaluate_retrieval(vec_c, vec_e, ground_truth, idx_to_claim_id, k=K)
# ----> 7 print(f"Mean Recall: {results_df['recall'].mean():.2%}")
#       8 print(f"Perfect Recall: {(results_df['recall'] == 1).sum()} / {len(results_df)}")
#       9 print(f"Zero Recall: {(results_df['recall'] == 0).sum()} / {len(results_df)}")
#
# File ~/.local/share/JetBrains/Toolbox/apps/pycharm/plugins/python-ce/helpers/pydev/_pydevd_bundle/pydevd_frame.py:755, in PyDBFrame.trace_dispatch(self, frame, event, arg)
#     753 # if thread has a suspend flag, we suspend with a busy wait
#     754 if info.pydev_state == STATE_SUSPEND:
# --> 755     self.do_wait_suspend(thread, frame, event, arg)
#     756     # No need to reset frame.f_trace to keep the same trace function.
#     757     return self.trace_dispatch
#
# File ~/.local/share/JetBrains/Toolbox/apps/pycharm/plugins/python-ce/helpers/pydev/_pydevd_bundle/pydevd_frame.py:412, in PyDBFrame.do_wait_suspend(self, *args, **kwargs)
#     411 def do_wait_suspend(self, *args, **kwargs):
# --> 412     self._args[0].do_wait_suspend(*args, **kwargs)
#
# File ~/.local/share/JetBrains/Toolbox/apps/pycharm/plugins/python-ce/helpers/pydev/pydevd.py:1196, in PyDB.do_wait_suspend(self, thread, frame, event, arg, send_suspend_message, is_unhandled_exception)
#    1193         from_this_thread.append(frame_id)
#    1195 with self._threads_suspended_single_notification.notify_thread_suspended(thread_id, stop_reason):
# -> 1196     self._do_wait_suspend(thread, frame, event, arg, suspend_type, from_this_thread)
#
# File ~/.local/share/JetBrains/Toolbox/apps/pycharm/plugins/python-ce/helpers/pydev/pydevd.py:1211, in PyDB._do_wait_suspend(self, thread, frame, event, arg, suspend_type, from_this_thread)
#    1208             self._call_mpl_hook()
#    1210         self.process_internal_commands()
# -> 1211         time.sleep(0.01)
#    1213 self.cancel_async_evaluation(get_current_thread_id(thread), str(id(frame)))
#    1215 # process any stepping instructions
#
# KeyboardInterrupt:

# %%
# Plot Distribution
counts, bins, patches = plt.hist(results_df['recall'])

for count, patch in zip(counts, patches):
    plt.text(
        patch.get_x() + patch.get_width() / 2,
        count,
        int(count),
        ha='center',
        va='bottom'
    )
plt.xlabel("Recall@50", labelpad=15)
plt.ylabel("Number of Claims", labelpad=15)
plt.show()

# %%
# Test Cases

def test_claim(claim_id, k=10, show_evidences=True):
    row_idx = claims[claims['claim_id'] == claim_id].index[0]
    claim_text = claims.iloc[row_idx]['claim']

    expected = ground_truth.get(claim_id, set())
    retrieved_idx = [idx for idx, _ in retrieved[row_idx][:k]]
    hits = set(retrieved_idx) & expected

    print(f"[{claim_id}]: {claim_text[:60]}")
    print(f"Found: {len(hits)}/{len(expected)}")
    if show_evidences:
        for idx in retrieved_idx:
            marker = "[X]" if idx in expected else "[ ]"
            print(f"{marker} {evidences.iloc[idx]['evidence'][:70]}...")
    print()

def run_tests(claim_ids, k=10, show_evidences=True):
    total_recall = []
    perfect, partial, failed = 0, 0, 0

    for cid in claim_ids:
        expected = ground_truth.get(cid, set())
        if not expected:
            continue
        row_idx = claims[claims['claim_id'] == cid].index[0]
        retrieved_idx = {idx for idx, _ in retrieved[row_idx][:k]}
        recall = len(retrieved_idx & expected) / len(expected)
        total_recall.append(recall)

        if recall == 1:
            perfect += 1
        elif recall == 0:
            failed += 1
        else:
            partial += 1

        test_claim(cid, k, show_evidences)

    print(f"{len(total_recall)}@{np.mean(total_recall):.2%}")
    print(f"{perfect}-{partial}-{failed}")


def run_random_tests(n=10, k=10, show_evidences=True):
    claim_ids = list(ground_truth.keys())
    sample = np.random.choice(claim_ids, size=min(n, len(claim_ids)), replace=False)
    run_tests(sample, k, show_evidences)

# %%
# Run Test

run_tests([0, 5, 6, 9, 10], 50)
# Out:
# [0]: Global warming is driving polar bears toward extinction
# Found: 2/2
# [X] Rising global temperatures, caused by the greenhouse effect, contribut...
# [ ] Steven Amstrup and other U.S. Geological Survey scientists have predic...
# [ ] Bear hunting caught in global warming debate....
# [ ] Global warming is a major threat to global biodiversity....
# [ ] The extinction risk of global warming is the risk of species becoming ...
# [ ] However, in the short term, some polar bear populations in historicall...
# [ ] Recently amplified arctic warming has contributed to a continual globa...
# [ ] Warnings about the future of the polar bear are often contrasted with ...
# [ ] One of the main theories to the extinction is climate change....
# [ ] Studying the association between Earth climate and extinctions over th...
# [ ] Rising temperatures cause the sea ice to melt earlier in the year, dri...
# [ ] In Alaska, the effects of sea ice shrinkage have contributed to higher...
# [ ] As global average temperature increase exceeds about 3.5°C, model proj...
# [ ] Limiting new black carbon deposits in the Arctic could reduce global w...
# [ ] In an op-ed for The New York Times, he wrote, Ironically, much of the ...
# [ ] It has been claimed that polar bears will be able to adapt to terrestr...
# [ ] Current projected consequences of global warming include a largely ice...
# [ ] Retrieved 2010-08-28. the leading international network of climate sci...
# [ ] Global warming has led to decades of shrinking and thinning of the Arc...
# [ ] Overall, it is expected that climate change will result in the extinct...
# [ ] The trigger for these mass extinctions appears to be a warming of the ...
# [ ] Accumulation of heat-trapping greenhouse gases, mainly being emitted b...
# [ ] There is widespread consensus among scientists that human activity is ...
# [ ] The retreat of the Arctic sea ice will accelerate global warming, as l...
# [ ] Recent Research Shows Human Activity Driving Earth Towards Global Exti...
# [ ] Of the 19 recognized polar bear subpopulations, one is in decline, two...
# [ ] In a synthesis report published in Science in 2015, 22 leading marine ...
# [ ] Avoiding this future warming will require a large and rapid reduction ...
# [ ] impacts likely worsened due to global warming....
# [ ] 788 concluded that a global mean temperature increase of around 4 °C a...
# [ ] Reduction of the area of Arctic sea ice reduces the planets average al...
# [ ] Human activity is most likely responsible for climate warming....
# [ ] Worst of all, we have driven the rate of biological extinction, the pe...
# [ ] The current Arctic warming is leading to ancient carbon being released...
# [ ] a large scale global warming, with radical climate changes may result....
# [ ] Many physical impacts of global warming are already visible, including...
# [ ] The effects of global warming in the Arctic include rising temperature...
# [ ] Melting of this ice may release large quantities of methane, a powerfu...
# [ ] Extreme Weather Prompts Unprecedented Global Warming Alert....
# [ ] The statement goes on to assert that evidence is accumulating that wil...
# [ ] Increasing magnitudes of global warming increase the likelihood of sev...
# [ ] Long-term persistence enhances uncertainty about anthropogenic warming...
# [ ] As reported by the Intergovernmental Panel on Climate Change IPCC, mos...
# [ ] Most of the global warming since the mid-20th century is very likely d...
# [X] Environmental impacts include the extinction or relocation of many spe...
# [ ] The New York Times reported that the leading international network of ...
# [ ] The rate of the decline in entire Arctic ice coverage is accelerating....
# [ ] Burning hydrocarbons as fuel, producing carbon dioxide and water, is a...
# [ ] It is anticipated that continuing changes to the climate will have ser...
# [ ] Anthropogenic heat is a much smaller contributor to global warming tha...
#
# [5]: The sun has gone into lockdown which could cause freezing we
# Found: 0/3
# [ ] There has been no upward trend in the amount of the Suns energy reachi...
# [ ] Another line of evidence against the sun having caused recent climate ...
# [ ] Famine, economic collapse, a sun that cooks us: What climate change co...
# [ ] Climate models have been used to examine the role of the Sun in recent...
# [ ] Another line of evidence for the warming not being due to the Sun is h...
# [ ] One theory is that the climate may reach a tipping point where positiv...
# [ ] Orbital forcing from cycles in the earths orbit around the sun has, fo...
# [ ] a large scale global warming, with radical climate changes may result....
# [ ] There is some concern that a shutdown of thermohaline circulation coul...
# [ ] Long-term secular change in sunspot number is thought, by some scienti...
# [ ] Earth is very close to being in radiative equilibrium, the situation w...
# [ ] Patterns of solar irradiance and solar variation has been a main drive...
# [ ] One of the main theories to the extinction is climate change....
# [ ] As the Earths climate warms, we are seeing many changes: stronger, mor...
# [ ] Changes to Earths radiative equilibrium, that cause temperatures to ri...
# [ ] There is still a very poor understanding of the correlation between lo...
# [ ] Study author Katherine Richardson stresses, We note that the Earth has...
# [ ] Our results show that the observed rapid rise in global mean temperatu...
# [ ] Other likely changes include more frequent extreme weather events such...
# [ ] The ice age continues until the reduction in weathering causes an incr...
# [ ] If no mitigating actions are taken, significant disruptions in the Ear...
# [ ] Another example is the possibility for the Atlantic Meridional Overtur...
# [ ] If this energy balance is shifted, Earths surface becomes warmer or co...
# [ ] As the Sun is the Earths primary energy source, changes in incoming su...
# [ ] If the Sun was responsible for observed warming, warming of the tropos...
# [ ] Climate forcings are changes that cause temperatures to rise or fall, ...
# [ ] This could lead to changing, and for all emissions scenarios more unpr...
# [ ] In a 2019 CBS poll, 64% of the US population said that climate change ...
# [ ] Models are unable to reproduce the rapid warming observed in recent de...
# [ ] A 2007 NASA sponsored satellite-based study sheds light on the puzzlin...
# [ ] In the three decades since 1978, the combination of solar and volcanic...
# [ ] increased concentrations of greenhouse gases, solar luminosity, volcan...
# [ ] The Scientific Consensus on Climate Change....
# [ ] Decades of scientific research have shown that climate can change from...
# [ ] In 2009, further evidence was provided that changes in solar insolatio...
# [ ] For instance as oceans are warming and becoming more acidic, biodivers...
# [ ] The key danger posed by climate change is malnutrition or starvation d...
# [ ] This created a warming that later melted the ice and brought Earths te...
# [ ] The scientific consensus on climate change is that climate is changing...
# [ ] Rising global temperatures, caused by the greenhouse effect, contribut...
# [ ] Global warming could lead to substantial alterations in climate extrem...
# [ ] Causes of Climate Change over the Past 1000 Years....
# [ ] Even small changes in temperatures can lead to increased frequency of ...
# [ ] Problems of global warming, climate change, and their various negative...
# [ ] A shutdown or slowdown of the thermohaline circulation is a hypothesiz...
# [ ] The 2014 flip from the cool PDO phase to the warm phase, which vaguely...
# [ ] This is the case for the conclusions that the Earth system is warming ...
# [ ] The climatic conditions that cause this warning became more frequent b...
# [ ] These changes can influence the planetary climate....
# [ ] Even if the current and future projected human effects on Earths clima...
#
# [6]: The polar bear population has been growing.
# Found: 1/2
# [ ] Warnings about the future of the polar bear are often contrasted with ...
# [ ] Polar bear population sizes and trends are difficult to estimate accur...
# [ ] The growth of the human population in the Eurasian Arctic in the 16th ...
# [X] Of the 19 recognized polar bear subpopulations, one is in decline, two...
# [ ] However, in the short term, some polar bear populations in historicall...
# [ ] In Alaska, the effects of sea ice shrinkage have contributed to higher...
# [ ] Steven Amstrup and other U.S. Geological Survey scientists have predic...
# [ ] Rising global temperatures, caused by the greenhouse effect, contribut...
# [ ] The numbers taken grew rapidly in the 1960s, peaking around 1968 with ...
# [ ] In Nunavut, some Inuit have reported increases in bear sightings aroun...
# [ ] The polar bear tends to frequent areas where sea ice meets water, such...
# [ ] It has been claimed that polar bears will be able to adapt to terrestr...
# [ ] The polar bear is the most carnivorous member of the bear family, and ...
# [ ] Unlike brown and black bears, polar bears are capable of fasting for u...
# [ ] The polar bear is the most carnivorous species of bear, and its diet p...
# [ ] Bear hunting caught in global warming debate....
# [ ] Polar bears hunt their preferred food of seals from the edge of sea ic...
# [ ] Rising temperatures cause the sea ice to melt earlier in the year, dri...
# [ ] Natural predators of the bearded seal include polar bears, who rely on...
# [ ] Recently amplified arctic warming has contributed to a continual globa...
# [ ] This has had cascading effects, especially on grizzly bear populations...
# [ ] In the Kamchatka peninsula and several parts of coastal Alaska, brown ...
# [ ] Polar Discovery Continued Sea Ice Decline in 2005....
# [ ] Climate change is having a direct impact on the people that live in th...
# [ ] The rate of the decline in entire Arctic ice coverage is accelerating....
# [ ] For decades, large-scale hunting raised international concern for the ...
# [ ] As well as the regular seasonal cycle there has been an underlying tre...
# [ ] Arctic temperatures have increased and are predicted to continue to in...
# [ ] However, unusually hot, dry summers and mild winters throughout the re...
# [ ] Trends such as Arctic sea ice decline, reduced snow cover, evapotransp...
# [ ] Accelerated decline in the Arctic sea ice....
# [ ] The IPCC also indicate that, over the last 100 years, the annually ave...
# [ ] Arctic Permafrost Is Going Through a Rapid Meltdown , 70 Years Early....
# [ ] citation needed In 2012, a survey of caribou herds found that the loca...
# [ ] Observation with satellites show that Arctic sea ice area, extent, and...
# [ ] In 2019, a warning on climate change signed by 11,000 scientists from ...
# [ ] There is growing evidence that our climate is changing....
# [ ] Climate change is affecting the white tailed deer by changing their mi...
# [ ] rising sea levels, shrinking Arctic sea ice....
# [ ] The authors conclude that anthropogenic increases in greenhouse gases ...
# [ ] More of the Suns energy is now absorbed in these regions, contributing...
# [ ] Ringed seals are one of the primary prey of polar bears and killer wha...
# [ ] Nevertheless, as all the explorers who travelled closer and closer to ...
# [ ] The dominant cause of the warming since the 1950s is human activities....
# [ ] Climate models predict much greater warming in the Arctic than the glo...
# [ ] There is a clear human influence on the climate It is extremely likely...
# [ ] Therefore, as species that thrive in the lower areas of the region are...
# [ ] Sea ice coverage in the Arctic has shrunk at a much faster rate than i...
# [ ] The change was attributed to increasingly cold winters in the Arctic s...
# [ ] Due to the poleward migration of the planets isotherms about 56 km 35 ...
#
# [9]: Ironic study finds more CO2 has slightly cooled the planet
# Found: 1/1
# [ ] There is also a close correlation between CO2 and temperature, where C...
# [ ] This hypothesis suggests a negative feedback which would counter the e...
# [ ] Other scientists were initially sceptical and believed the greenhouse ...
# [ ] In that sense, the ice core CO2-temperature correlation remains an app...
# [ ] How do we know more CO2 is causing warming?....
# [ ] The surprising effect of this is that the global warming potential of ...
# [ ] Relevant to this dispute is the observation that Greenland ice cores o...
# [ ] Decades ago, they correctly predicted how much Earths temperature woul...
# [ ] The higher concentration of CO2 in the Martian thermosphere may explai...
# [ ] He says a greenhouse effect exists, and that carbon dioxide contribute...
# [ ] Analysis of carbon isotopes in atmospheric CO2 shows that the recent o...
# [X] This increase of CO2 and other long-lived greenhouse gases in Earths a...
# [ ] Some climate change denial groups say that because CO2 is only a trace...
# [ ] The large amount of CO2 in the atmosphere together with water vapour a...
# [ ] CO2 generation, on its own, is too small to account for the rise....
# [ ] Human activities have caused CO2 to increase above levels not seen in ...
# [ ] However some research shows that black carbon will increase global war...
# [ ] Further research has demonstrated a reliable correlation between CO2 l...
# [ ] During the glacial cycles, there was a high correlation between CO2 co...
# [ ] Since global warming is attributed to increasing atmospheric concentra...
# [ ] There is evidence from one study that Antarctica is warming as a resul...
# [ ] Its yet another reason to be very seriously concerned about the amount...
# [ ] The 1990 IPCC First Assessment Report estimated that equilibrium clima...
# [ ] CO2 is a heat-trapping greenhouse gas which causes global warming, whi...
# [ ] The higher CO2 levels led to an additional climate warming ranging bet...
# [ ] Isotopes of carbon and oxygen indicate a shift to a global cooling cli...
# [ ] The CO2 fertiliser effect has been greatly overestimated during Free-A...
# [ ] Less direct geological evidence indicates that CO2 values have not bee...
# [ ] Also, a report by the Royal Netherlands Institute for Sea Research sta...
# [ ] This additional CO2 led to a projected increase in warming of between ...
# [ ] An alternate scenario would keep the warming to below this if climate ...
# [ ] Evidence from the geological record is consistent with the physics tha...
# [ ] Despite a weak early Sun, the greenhouse effect from a thick carbon di...
# [ ] It is likely that greenhouse gases would have caused more warming than...
# [ ] Following the start of the Industrial Revolution, atmospheric CO2 conc...
# [ ] The changes in temperature have been associated with increasing concen...
# [ ] A survey of peer-reviewed scientific papers published between 1965 and...
# [ ] Watts Up With That features material disputing the scientific consensu...
# [ ] We cant pin it down, but it certainly is consistent with the influence...
# [ ] Correlation of CO2 and temperature is not part of this evidence....
# [ ] According to research published in Nature Geoscience, human emissions ...
# [ ] The paper suggested that the global warming due to greenhouse gases wo...
# [ ] Carbon dioxide is a greenhouse gas that increases radiative forcing an...
# [ ] Some stratospheric cooling is also predicted from increases in greenho...
# [ ] In a synthesis report published in Science in 2015, 22 leading marine ...
# [ ] Atmospheric CO2 has risen over the last 150 years to current levels of...
# [ ] In the IPCC Fifth Assessment Report the increase in CO2 was estimated ...
# [ ] Although the temperature drops foreseen by this mechanism have now bee...
# [ ] Carbon dioxide is the primary greenhouse gas that is contributing to r...
# [ ] Rapid atmospheric CO2 changes associated with the 8,200-years-B.P....
#
# [10]: Human additions of CO2 are in the margin of error of current
# Found: 1/1
# [ ] Human activities have caused CO2 to increase above levels not seen in ...
# [ ] The oceans act as an enormous carbon sink, and have taken up about a t...
# [ ] How do we know more CO2 is causing warming?....
# [ ] While CO2 absorption and release is always happening as a result of na...
# [ ] Since global warming is attributed to increasing atmospheric concentra...
# [ ] This increase of CO2 and other long-lived greenhouse gases in Earths a...
# [ ] According to research published in Nature Geoscience, human emissions ...
# [ ] Evidence from the geological record is consistent with the physics tha...
# [ ] Following the start of the Industrial Revolution, atmospheric CO2 conc...
# [ ] During the glacial cycles, there was a high correlation between CO2 co...
# [ ] Analysis of carbon isotopes in atmospheric CO2 shows that the recent o...
# [ ] The global mean CO2 concentration is currently rising at a rate of app...
# [ ] The surprising effect of this is that the global warming potential of ...
# [ ] Rapid atmospheric CO2 changes associated with the 8,200-years-B.P....
# [ ] Global annual mean CO2 concentration has increased by more than 45% si...
# [ ] CO2 is a heat-trapping greenhouse gas which causes global warming, whi...
# [X] More recently, anthropogenic activities have steadily increased the ca...
# [ ] Also, a report by the Royal Netherlands Institute for Sea Research sta...
# [ ] On 12 November 2015, NASA scientists reported that carbon dioxide in t...
# [ ] Some climate change denial groups say that because CO2 is only a trace...
# [ ] Current annual increase in atmospheric CO2 is approximately 4 gigatons...
# [ ] Atmospheric CO2 has risen over the last 150 years to current levels of...
# [ ] Relevant to this dispute is the observation that Greenland ice cores o...
# [ ] For example, through the early-mid Eocene volcanic outgassing, the oxi...
# [ ] CO2 currently forms about 410 parts per million ppm of earths atmosphe...
# [ ] Less direct geological evidence indicates that CO2 values have not bee...
# [ ] Anthropogenic CO2 cant be changing climate, because CO2 is only a trac...
# [ ] At the end of an ice age, warming from increased CO2 would increase th...
# [ ] In a synthesis report published in Science in 2015, 22 leading marine ...
# [ ] The correlation between the decrease of CO2 in the Pleistocene and the...
# [ ] Paleobotanical Evidence for Near Present-Day Levels of Atmospheric CO2...
# [ ] The higher CO2 levels led to an additional climate warming ranging bet...
# [ ] The gradual intensification of this ice age over the last 3 million ye...
# [ ] On the timescale of centuries to millennia, the magnitude of global wa...
# [ ] Carbon dioxide is a greenhouse gas that increases radiative forcing an...
# [ ] Keelings Tellus article of 1960 presented the first monthly CO2 record...
# [ ] The changes in temperature have been associated with increasing concen...
# [ ] Global warming is the result of increasing atmospheric carbon dioxide ...
# [ ] There is also a close correlation between CO2 and temperature, where C...
# [ ] As more CO2 and heat are absorbed by the ocean, it is acidifying and o...
# [ ] Presently, oceans are CO2 sinks, and represent the largest active carb...
# [ ] This figure accounts for CO2 molecules being removed from the atmosphe...
# [ ] CO2 in the atmosphere just exceeded 415 parts per million for the firs...
# [ ] Further research has demonstrated a reliable correlation between CO2 l...
# [ ] As stated earlier, the CO2 released by soil respiration is a greenhous...
# [ ] the CO2 concentration already released into the atmosphere since the b...
# [ ] The reason for this is that human activities are adding CO2 to the atm...
# [ ] The beginning of human agriculture during the current Holocene epoch m...
# [ ] After about a thousand years, 20% to 30% of human-emitted CO2 will rem...
# [ ] Increasing atmospheric CO2 concentrations lead to further acidificatio...
#
# 5@70.00%
# 3-1-1

# %%
# Run Random Test

run_random_tests(20, 50, False)
# Out:
# [1097]: The impact on calcification, metabolism, growth, fertility a
# Found: 2/2
#
# [135]: Carbon emissions are declining in most rich nations and have
# Found: 4/5
#
# [1313]: Coral bleaching has devastated 93% of the Great Barrier Reef
# Found: 2/2
#
# [967]: He said: We have had five warming cycles since about 900AD,
# Found: 0/1
#
# [1743]: Arctic sea ice has shrunk by an area equal to Western Austra
# Found: 2/2
#
# [382]: The amount of energy used to construct solar and wind facili
# Found: 1/1
#
# [2187]: Scientific analysis of past climates shows that greenhouse g
# Found: 2/3
#
# [2570]: The IPCC statement on Amazon rain forests is correct.
# Found: 1/2
#
# [577]: Heatwaves are far more intense than when my parents were gro
# Found: 2/2
#
# [6]: The polar bear population has been growing.
# Found: 1/2
#
# [551]: Gone are the days when scientists drew a bright line dividin
# Found: 0/2
#
# [2845]: The original global temperature schematic which appeared in
# Found: 4/4
#
# [717]: Scientists used to think that ice sheets could take millenni
# Found: 2/3
#
# [2992]: The measurements of the amount of CO2 made at the Mauna Loa
# Found: 1/1
#
# [1142]: Even as sea ice in the Arctic has seen a rapid and consisten
# Found: 2/4
#
# [1170]: If a major hurricane is approaching with a predicted storm s
# Found: 0/1
#
# [1868]: Currently, Florida is one of only five states in the nation
# Found: 2/2
#
# [1486]: So that means that probably about half, maybe half of that n
# Found: 3/3
#
# [2330]: Arctic sea ice has been retreating over the past 30 years.
# Found: 3/3
#
# [1204]: Back in the late 1980s, the UN claimed that if global warmin
# Found: 1/5
#
# 20@69.17%
# 10-7-3

# %%
# MRR

def compute_mrr(retrieved, ground_truth, idx_to_claim_id):
    rrs = []
    for row_idx, claim_id in idx_to_claim_id.items():
        if claim_id not in ground_truth:
            continue
        expected = ground_truth[claim_id]
        for rank, (idx, _) in enumerate(retrieved[row_idx], 1):
            if idx in expected:
                rrs.append(1 / rank)
                break
        else:
            rrs.append(0)
    return np.mean(rrs)

# %%
# Final Results

results_dict = {
    'approach': 'Dense',
    'k_values': k_values,
    'recall_scores': recall_scores,
    'mrr': compute_mrr(retrieved, ground_truth, idx_to_claim_id),
}

np.save('../a2/results_a2.npy', results_dict)

# %%
# Final Results

per_claim_recalls = results_df['recall'].values

results_dict = {
    'approach': 'Dense',
    'k_values': k_values,
    'recall_scores': recall_scores,
    'mrr': compute_mrr(retrieved, ground_truth, idx_to_claim_id),
    'precision_at_k': {k: compute_precision_at_k(retrieved, ground_truth, idx_to_claim_id, k) for k in k_values},
    'per_claim_recalls': per_claim_recalls,
    'claim_ids': list(results_df['claim_id']),
}

np.save('results_a2.npy', results_dict)
